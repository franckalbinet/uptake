# %% [markdown]
# # Loading
#
# > Data loading utilities

# %%
#| default_exp loading

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
import fastcore.all as fc
from pathlib import Path
import pandas as pd

# %%
#| export
def load_vnklm():
    "Load Margot Vanheukelom KULeuven data."
    fname = Path('../_data/Margot_clean-data.xlsx')
    df = pd.read_excel(fname, nrows=207)
    
    coi = ['reference', 'soil code', 'dataset', 
           'soil class (WRB)', 'clay (%)', 'SOC (%)',
           'pH', 'CEC (cmolc/kg)', 'exchK (cmolc/kg)',
           'NH4ss (mmol/L)', 'contact time (d)', 'CR (kg/kg)',
           'predicted CR (kg/kg) Absalom1999', 
           'predicted CR (kg/kg) Absalom2001',
           'predicted CR (kg/kg) Tarsitano2011']
    
    names = ['ref', 'soil_code', 'ds', 'soil_class', 
             'clay', 'soc', 'ph', 'cec', 'kex', 'nh4',
             'time', 'cr', 'cr_absa_1999', 'cr_absa_2001', 'cr_tars_2011']
    
    df = df[coi]
    df.columns = names
    df = df.dropna(subset=['cr'])
    df = df[df['soil_class'] != "/"]
    
    col_features = ['clay', 'soc', 'cec', 'ph', 'kex', 'nh4', 'time']
    col_target = ['cr']
    return df

# %%
#|eval: false
load_vnklm()
# Out:
#                  ref soil_code            ds soil_class       clay       soc  \
# 0       Smolders1997         2    literature         LV  12.600000  2.570000
# 1       Smolders1997         5    literature         FL  21.900000  5.450000
# 2       Smolders1997         9    literature         LV   3.300000  2.900000
# 3       Smolders1997        10    literature         PZ   2.400000  1.890000
# 4       Smolders1997        13    literature         AT   4.500000  1.600000
# ..               ...       ...           ...        ...        ...       ...
# 143  Vanheukelom2024    LAG2+K  toposequence         CM  21.585497  1.852270
# 144  Vanheukelom2024    LAG3+K  toposequence         AC  44.839196  0.557858
# 145  Vanheukelom2024    LAG4+K  toposequence         CM  38.644722  1.847666
# 146  Vanheukelom2024    LAG5+K  toposequence         CM  32.338793  1.792038
# 147  Vanheukelom2024    LAG6+K  toposequence         CM  29.386730  1.842415
#
#            ph        cec       kex       nh4  time        cr  cr_absa_1999  \
# 0    5.040000  13.800000  0.180000  0.030000    67  0.265500      0.000250
# 1    5.680000  28.200000  0.380000  0.040000    67  0.089000      0.000082
# 2    5.170000   9.300000  0.200000  0.070000    67  0.627100      0.003042
# 3    4.690000   5.400000  0.150000  0.040000    67  0.285000      0.005711
# 4    4.680000   5.100000  0.900000  0.160000    67  0.044600      0.001039
# ..        ...        ...       ...       ...   ...       ...           ...
# 143  5.943333  24.512791  1.215386  0.045137    80  0.020553      0.000071
# 144  3.836667   9.868775  0.405093  0.402177    80  3.274398      0.000020
# 145  4.763333  27.875549  0.630881  0.571004    80  0.317191      0.000026
# 146  4.450000  22.671039  1.088063  0.366031    80  0.048163      0.000034
# 147  5.506667  33.705742  1.161356  0.017295    80  0.054261      0.000041
#
#      cr_absa_2001  cr_tars_2011
# 0        0.048243      0.136174
# 1        0.026420      0.073079
# 2        0.151939      0.287474
# 3        0.161266      0.332143
# 4        0.027919      0.046458
# ..            ...           ...
# 143      0.007756      0.025604
# 144      0.084212      0.153852
# 145      0.051035      0.106087
# 146      0.018101      0.039714
# 147      0.006679      0.023132
#
# [148 rows x 15 columns]

# %%
#| hide
import nbdev; nbdev.nbdev_export()
